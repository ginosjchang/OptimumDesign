# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(5)

gd_count = [0, 0, 37, 5, 58]
fr_count = [0, 2, 24, 55, 19]
nm_count = [0, 1, 18, 60, 21]
dfp_count = [0, 1, 14, 57, 28]

width = 0.2

plt.bar(x, gd_count, width=width, label='GD')
plt.bar(x + width, fr_count, width=width, label="FR")
plt.bar(x + 2 * width, nm_count, width=width, label="NM")
plt.bar(x + 3 * width, dfp_count, width=width, label="DFP")
plt.xticks(x + 2*width, x)
plt.ylabel('The cumulative count')
plt.xlabel('The number of correct answers')
plt.title('Statistical Results')
plt.legend(bbox_to_anchor=(1,1), loc='upper left')
plt.show()

# %%
np.mean([1])
# Out:
# 1.0
